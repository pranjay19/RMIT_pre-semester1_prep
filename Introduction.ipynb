# %% [markdown]
# <h1>Day 3----></h1>

# %% [markdown]
# Conditionals(if,elif,else)

# %%
grade = 75

if grade >= 80:
    print("High Distinction (HD)")
elif grade >= 70:
    print("Distinction (DI)")
elif grade >= 60:
    print("Credit (CR)")
else:
    print("Pass (PA) or Fail (NN)")
    
# Output: Distinction (DI)
# Out:
# Distinction (DI)

# %% [markdown]
# Applying For loop in List

# %%
messy_data = ["  APPLE ", "bAnAnA", " CHERRY  "]

# %%
updated_data=[]

# %%
for i in messy_data:
    updated_data.append(i.strip().lower())

# %%
print(updated_data)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# Applying for loop in Dictionary

# %%
student_marks = {"Alex": 85, "Jane": 92, "Sam": 45}

# %%
for name,marks in student_marks.items():
    if marks>90:
        print(f"{name} has shown outstanding performance")
    else:
        print(f"{name} has shown good performance")

print(f"Thanks everyone for your efforts")
# Out:
# Alex has shown good performance
# Jane has shown outstanding performance
# Sam has shown good performance
# Thanks everyone for your efforts

# %% [markdown]
# Applying while loop

# %%
processing_count=5

while(processing_count>0):
    print(f"processing in progress")
    processing_count=processing_count-1

print(f"processing completed !")
# Out:
# processing in progress
# processing in progress
# processing in progress
# processing in progress
# processing in progress
# processing completed !

# %%
student_grades = [85, "Missing", 92, 45, 78]

for grade in student_grades:
    # 1. Skip the missing data
    if grade == "Missing":
        print("Skipping missing grade...")
        continue 
        
    # 2. Stop entirely if someone failed too badly
    if grade < 50:
        print(f"Critical failure found: {grade}. Halting analysis.")
        break
        
    print(f"Processing grade: {grade}")
# Out:
# Processing grade: 85
# Skipping missing grade...
# Processing grade: 92
# Critical failure found: 45. Halting analysis.

# %%
# A list containing two sub-lists
university_classes = [
    ["Alex", "Jane", "Sam"], 
    ["Chris", "Pat"]
]

# The outer loop grabs the sub-lists
for classroom in university_classes:
    print("--- New Classroom ---")
    
    # The inner loop grabs the individual students
    for student in classroom:
        print(student)
# Out:
# --- New Classroom ---
# Alex
# Jane
# Sam
# --- New Classroom ---
# Chris
# Pat

# %% [markdown]
# <h2>Day 3 Mini Challange</h2>

# %%
List=[15, 8, 42, "Error", 23, 4]

# %%
for i in List:
    if type(i)==str:
        continue
    if i>20:
        print(i)
# Out:
# 42
# 23

# %% [markdown]
# <h1>Day 4----></h1>

# %% [markdown]
# Defining a function

# %%
def Welcome():
    print(f"Hi there, we welcome you to day 4!")

# %%
Welcome()
# Out:
# Hi there, we welcome you to day 4!

# %% [markdown]
# Understanding parameters & Arguments

# %%
def sum(a,b):
    return a+b

# %%
print(sum(10,20))
# Out:
# 30

# %%
def calculate_score():
    final_grade = 95 # This variable only exists inside this block
    return final_grade

# This will CRASH your program with a NameError! 
# The outside code has no idea what 'final_grade' is.
result=calculate_score()
print(result)
# Out:
# 95

# %% [markdown]
# Day 4 Mini-Challenge

# %%
def clean_student_id(raw_id):
    return raw_id.strip().lower()

# %%
print(clean_student_id("  S3900000  "))
# Out:
# s3900000

# %% [markdown]
# 🌟 Level-Up 1: Default Parameters

# %%
# We set a default value of "Melbourne" for the campus
def enroll_student(name, campus="Melbourne"):
    return f"{name} is enrolled at the {campus} campus."

# If we don't provide a campus, it defaults to Melbourne!
print(enroll_student("Alex")) 
# Output: Alex is enrolled at the Melbourne campus.

# But we can overwrite it if we want to:
print(enroll_student("Jane", "Vietnam")) 
# Output: Jane is enrolled at the Vietnam campus.
# Out:
# Alex is enrolled at the Melbourne campus.
# Jane is enrolled at the Vietnam campus.

# %% [markdown]
# 🌟 Level-Up 2: Returning Multiple Things

# %%
def analyze_price(raw_price):
    clean_price = float(raw_price.replace("$", ""))
    tax = clean_price * 0.10
    
    # Returning TWO things at once
    return clean_price, tax 

# You catch them on the outside using two variables
final_price, calculated_tax = analyze_price("$100.00")

print(f"Price: {final_price}, Tax: {calculated_tax}")
# Output: Price: 100.0, Tax: 10.0
# Out:
# Price: 100.0, Tax: 10.0

# %% [markdown]
# <h1>Day 5-----></h1>

# %% [markdown]
# Core string methods

# %%
Name="PrAnJaY"

# %%
Name.lower()
# Out:
# 'pranjay'

# %%
Name.upper()
# Out:
# 'PRANJAY'

# %%
Strip_function="   Hello   "

# %%
Strip_function.strip()
# Out:
# 'Hello'

# %%
replace_function="old_name"

# %%
replace_function.replace("old","new")
# Out:
# 'new_name'

# %%
Split_string="Hello,pranjay,how,are,you"
Split_string.split(",")
# Out:
# ['Hello', 'pranjay', 'how', 'are', 'you']

# %% [markdown]
# Introduction to Regex (The Heavy Machinery)

# %%
import re

# %%
import re

messy = "Wait... is this 100% correct?!?!"

# Find everything that isn't a word/number/space, and delete it.
clean = re.sub(r"[^\w\s]", "", messy)

print(clean)
# Out:
# Wait is this 100 correct

# %%
import re

messy_string = "The price is 45 dollars and 99 cents."

# The pattern r"\d+" means: "Find any digit (\d), and grab 
# the whole cluster of them (+)"
numbers = re.findall(r"\d+", messy_string)

print(numbers) 
# Output: ['45', '99']
# Out:
# ['45', '99']

# %% [markdown]
# <h1>Day 6----></h1>

# %%
# %pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.3 MB 5.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/12.3 MB 4.6 MB/s eta 0:00:03
#    -------- ------------------------------- 2.6/12.3 MB 4.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.4/12.3 MB 4.2 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.3 MB 4.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/12.3 MB 4.1 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.3 MB 4.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.8/12.3 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.3 MB 4.1 MB/s eta 0:00:02
#    --------------------------- ------------ 8.4/12.3 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.2/12.3 MB 4.0 MB/s eta 0:00:01
# ...

# %%
import numpy as np

# %%
array_new=np.array([1,2,4,5])

# %%
array_new
# Out:
# array([1, 2, 4, 5])

# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.3-cp312-cp312-win_amd64.whl (9.8 MB)
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# creating series

# %%
series_setup=pd.Series(["pranjay", "guleria" , 21 ], index=["firstname","lastname","rollnumber"])

# %%
print(series_setup)
# Out:
# firstname     pranjay
# lastname      guleria
# rollnumber         21
# dtype: object

# %%
dataframe_setup=pd.DataFrame({"Player": ["Virat", "Rohit", "Surya", "Hardik"],
    "Matches": [115, 148, 48, 87],
    "Strike_Rate": [137.9, 139.2, 175.7, 142.1]})

# %%
print(dataframe_setup)
# Out:
#    Player  Matches  Strike_Rate
# 0   Virat      115        137.9
# 1   Rohit      148        139.2
# 2   Surya       48        175.7
# 3  Hardik       87        142.1

# %%
dataframe_setup.head()
# Out:
#    Player  Matches  Strike_Rate
# 0   Virat      115        137.9
# 1   Rohit      148        139.2
# 2   Surya       48        175.7
# 3  Hardik       87        142.1

# %%
dataframe_setup.tail()
# Out:
#    Player  Matches  Strike_Rate
# 0   Virat      115        137.9
# 1   Rohit      148        139.2
# 2   Surya       48        175.7
# 3  Hardik       87        142.1

# %%
dataframe_setup.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player       4 non-null      str
#  1   Matches      4 non-null      int64
#  2   Strike_Rate  4 non-null      float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 228.0 bytes

# %%
dataframe_setup.describe()
# Out:
#           Matches  Strike_Rate
# count    4.000000     4.000000
# mean    99.500000   148.725000
# std     42.430335    18.068827
# min     48.000000   137.900000
# 25%     77.250000   138.875000
# 50%    101.000000   140.650000
# 75%    123.250000   150.500000
# max    148.000000   175.700000

# %%
dataframe_setup.shape
# Out:
# (4, 3)

# %% [markdown]
# Testing branch_05
